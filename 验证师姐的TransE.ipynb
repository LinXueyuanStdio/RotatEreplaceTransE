# %%
import pyecharts

# %%
from loss import data

# %%
import pyecharts

# %%
import pyecharts.options as opts
from pyecharts.charts import Line

# %%
x_data, y_data = [], []
for i in data:
    x_data.append(i[0])
    y_data.append(i[1])


Line().set_global_opts(
        tooltip_opts=opts.TooltipOpts(is_show=False),
        xaxis_opts=opts.AxisOpts(type_="category"),
        yaxis_opts=opts.AxisOpts(
            type_="value",
            axistick_opts=opts.AxisTickOpts(is_show=True),
            splitline_opts=opts.SplitLineOpts(is_show=True),
        ),
    ).add_xaxis(xaxis_data=x_data).add_yaxis(
        series_name="",
        y_axis=y_data,
        symbol="emptyCircle",
        is_symbol_show=True,
        label_opts=opts.LabelOpts(is_show=False),
    ).render_notebook()
# 训练，3531次循环得到的loss，loss没有下降
# Out:
# /home/lxy/.local/lib/python3.6/site-packages/pyecharts/charts/chart.py:14: PendingDeprecationWarning: pyecharts 所有图表类型将在 v1.9.0 版本开始强制使用 ChartItem 进行数据项配置 :)
#   super().__init__(init_opts=init_opts)
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="2a72258a9856416493f0c7326268e619" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_2a72258a9856416493f0c7326268e619 = echarts.init(
#                     document.getElementById('2a72258a9856416493f0c7326268e619'), 'white', {renderer: 'canvas'});
#                 var option_2a72258a9856416493f0c7326268e619 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
# ...

# %% [markdown]
# ### 工作
# 1. 跑通了师姐的RDGCN以及RotatE；TransE部分的代码能跑，但是有问题；
# 2. 尝试修复数据，没有成功
# 3. ATentsembed.txt是 \[实体数, 200\] 的嵌入矩阵，我们只要用RotatE训练出这个矩阵就行了
#
# ### 遇到的问题
# 1. 数据集不完整
#
#   `atts_2`, `ent_ids_2` -> `att_triple_2`, `att2id_2`, `att_val2id_2`
#
#   缺少atts_2。DBP15k
#
#   只有fr_en提供了`att_triple_2`, `att2id_2`, `att_val2id_2`这3个文件，zh_en和ja_en都缺`att2id_2`, `att_val2id_2`
# 2. TransE的代码不能直接用，需要重写（训练3531次循环得到的loss，loss没有下降）
#
# ### 下一步
# 1. 修复数据集（zh_en,ja_en）
# 2. 实现模型（TransE和RotatE）
# 3. 评价 Hits@n in zh_en,ja_en,fr_en，验证：使用RotatE替换TransE后，指标上升或下降多少
